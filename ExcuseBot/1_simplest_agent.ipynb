# %%
import setup
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %%
import time
from openai.types.responses import ResponseTextDeltaEvent
result = Runner.run_streamed(agent, "What are the top 10 most popular fruits eaten worldwide?")

async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
        time.sleep(0.6)  # Simulate processing time
# Out:
# While I understand your request, it seems like you're looking for information rather than an excuse. However, if you're seeking to create an excuse based on this information, here's a playful approach:
#
# ---
#
# **Excuse Scenario:** You forgot to bring a fruit to a meeting because you were too busy researching the top 10 most popular fruits eaten worldwide.
#
# **Excuse:**
#
# "Hey [Name], I hope you're doing well. I wanted to explain why I didn't bring a fruit to the meeting today. I got so engrossed in researching the top 10 most popular fruits eaten worldwide—bananas, apples, oranges, grapes, pineapples, mangoes, strawberries, watermelons, lemons, and pomegranates—that I completely lost track of time! I guess my passion for global fruit consumption got the better of me. I'll make sure to bring a fruit next time to show my appreciation for the variety we enjoy around the world."
#
# ---
#
# Feel free to adjust the excuse to fit your specific situation!
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[8], line 5
#       2 from openai.types.responses import ResponseTextDeltaEvent
#       3 result = Runner.run_streamed(agent, "What are the top 10 most popular fruits eaten worldwide?")
# ----> 5 async for event in result.stream_events():
#       6     if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
#       7         print(event.data.delta, end="", flush=True)
#
# File /workspaces/ceu-ai-engineering-class/.venv/lib/python3.13/site-packages/agents/result.py:325, in RunResultStreaming.stream_events(self)
#     322     break
#     324 try:
# --> 325     item = await self._event_queue.get()
#     326 except asyncio.CancelledError:
#     327     cancelled = True
#
# File /usr/local/lib/python3.13/asyncio/queues.py:186, in Queue.get(self)
#     184 self._getters.append(getter)
#     185 try:
# --> 186     await getter
#     187 except:
#     188     getter.cancel()  # Just in case getter is not done yet.
#
# CancelledError:
